# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_details(link):
    link = link + '#wurs'
    r = requests.get(link)
    page_body = r.text

    soup = BeautifulSoup(page_body, 'html.parser')
    
    # will contain total_academic_fac_staff, inter_academic_fac_staff, total_students, inter_students
    results = []
    for name in ['total faculty', 'inter faculty', 'total student', 'total inter']:
        try:
            elem = int(soup.find('div', class_= name).find('div', class_='number').text.replace(',',''))
        except AttributeError:
            elem = None
        results.append(elem)
    return results

# %%
'''r = requests.get('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt')
page_body = r.text
json_data = r.json()
#print(type(json_data))
i = 0
for key, value in json_data.items():
    i = i +1
    #print(str(key) + " -> " + str(value))
    print(str(key))
    if i > 15:
        break'''
#print(json_data['columns'])

cols = ['QSrank', 'region', 'country', 'Faculty members (total)', 'Faculty members (inter.)', 'Students (total)', 'Students (inter.)']

df = pd.DataFrame(columns=cols)



for i, uni in enumerate(json_data['data'][:200]):
    soup = BeautifulSoup(uni['uni'], 'html.parser')
    details_link = 'https://www.topuniversities.com' + soup.a['href']
    name = soup.a.string
    country = uni['location']
    region = uni['region']
    rank = uni['overall_rank'] 
    details = get_details(details_link)
    # we saw that for some reason the uni ranked 281 appeared in the top-200.
    # this check avoids having it in our ranking
    if int(rank) <= 200:
        df.loc[name] = ([rank, region, country] + details)
    print("Progression: " + '{0:.1f}'.format(100*i/200.0) + "%", end="\r")




'''test_uni = json_data['data'][0]
soup = BeautifulSoup(test_uni['uni'], 'html.parser')
name = soup.a.string
country = test_uni['location']
region = test_uni['region']
rank = test_uni['overall_rank']'''
#print(name + "\n" + rank + "\n" + country + "\n" + region)
#print(test_uni)
#print(type(json_data['data'][0]))
#print(len(json_data['data']))
#print(json_data['data'][21])

df.head()

# %%
#df[pd.isnull(df['Faculty members (total)'])]
df.head(200)
# Out:
#                                                    QSrank         region  \
# Massachusetts Institute of Technology (MIT)             1  North America
# Stanford University                                     2  North America
# Harvard University                                      3  North America
# California Institute of Technology (Caltech)            4  North America
# University of Cambridge                                 5         Europe
# University of Oxford                                    6         Europe
# UCL (University College London)                         7         Europe
# Imperial College London                                 8         Europe
# University of Chicago                                   9  North America
# ETH Zurich - Swiss Federal Institute of Technology     10         Europe
# Nanyang Technological University, Singapore (NTU)      11           Asia
# Ecole Polytechnique Fédérale de Lausanne (EPFL)        12         Europe
# ...

# %%
test = json_data['data'][0]

link_test = 'https://www.topuniversities.com/universities/massachusetts-institute-technology-mit#wurs'

r = requests.get(link_test)
page_body = r.text

soup = BeautifulSoup(page_body, 'html.parser')

total_academic_fac_staff = int(soup.find('div', class_='total faculty').find('div', class_='number').text.replace(',',''))
inter_academic_fac_staff = int(soup.find('div', class_='inter faculty').find('div', class_='number').text.replace(',',''))
total_students = int(soup.find('div', class_='total student').find('div', class_='number').text.replace(',',''))
inter_students = int(soup.find('div', class_='total inter').find('div', class_='number').text.replace(',',''))

print(total_academic_fac_staff)
print(inter_academic_fac_staff)
print(total_students)
print(inter_students)




#true_link = '/universities/massachusetts-institute-technology-mit'
# Out:
# 2982
# 1679
# 11067
# 3717
